# %%
import hvplot.pandas
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from bokeh.sampledata.sprint import sprint as df
# %matplotlib inline

# %%
region_csv = Path("Resource/Region_summary_NSW_STE.csv")
NSW_mortgages = pd.read_csv(region_csv)
NSW_mortgages.head()
# Out:
#   Measure Code                          Parent Description  \
# 0     ERP_P_20  Estimated resident population - at 30 June
# 1       ERP_21  Estimated resident population - at 30 June
# 2     ERP_M_20  Estimated resident population - at 30 June
# 3     ERP_F_20  Estimated resident population - at 30 June
# 4       ERP_19  Estimated resident population - at 30 June
#
#                                      Description  2011  2015       2016  \
# 0            Estimated resident population (no.)   NaN   NaN  7732858.0
# 1               Population density (persons/km2)   NaN   NaN        9.7
# 2    Estimated resident population - males (no.)   NaN   NaN  3833807.0
# 3  Estimated resident population - females (no.)   NaN   NaN  3899051.0
# 4                     Median age - males (years)   NaN   NaN       36.7
#
#         2017       2018       2019       2020       2021  2022
# 0  7850871.0  7945580.0  8034305.0  8094317.0  8093815.0   NaN
# 1        9.8        9.9       10.0       10.1       10.1   NaN
# 2  3894093.0  3945584.0  3992323.0  4021817.0  4023278.0   NaN
# 3  3956778.0  3999996.0  4041982.0  4072500.0  4070537.0   NaN
# 4       36.7       36.7       36.8       37.2       37.7   NaN

# %%
print(NSW_mortgages.isnull().sum())
print(NSW_mortgages[NSW_mortgages.isnull().any(axis=1)])
# Out:
# Measure Code            0
# Parent Description      0
# Description             0
# 2011                  584
# 2015                  793
# 2016                  149
# 2017                  494
# 2018                  457
# 2019                  445
# 2020                  525
# 2021                  383
# 2022                  803
# dtype: int64
#     Measure Code                                 Parent Description  \
# 0       ERP_P_20         Estimated resident population - at 30 June
# 1         ERP_21         Estimated resident population - at 30 June
# 2       ERP_M_20         Estimated resident population - at 30 June
# 3       ERP_F_20         Estimated resident population - at 30 June
# 4         ERP_19         Estimated resident population - at 30 June
# ..           ...                                                ...
# 808   LTENURE_10  Experimental land tenure estimates - year ende...
# 809   LTENURE_11  Experimental land tenure estimates - year ende...
# 810   LTENURE_12  Experimental land tenure estimates - year ende...
# 811   LTENURE_13  Experimental land tenure estimates - year ende...
# 812   LTENURE_14  Experimental land tenure estimates - year ende...
#
#                                        Description  2011  2015        2016  \
# 0              Estimated resident population (no.)   NaN   NaN   7732858.0
# 1                 Population density (persons/km2)   NaN   NaN         9.7
# 2      Estimated resident population - males (no.)   NaN   NaN   3833807.0
# 3    Estimated resident population - females (no.)   NaN   NaN   3899051.0
# 4                       Median age - males (years)   NaN   NaN        36.7
# ..                                             ...   ...   ...         ...
# 808                Multiple-use public forest (ha)   NaN   NaN   2189712.0
# 809                      Other Crown purposes (ha)   NaN   NaN   1591712.0
# 810                          Other Crown land (ha)   NaN   NaN    398088.0
# 811                Land tenure not classified (ha)   NaN   NaN    392450.0
# 812                         Total land tenure (ha)   NaN   NaN  80129856.0
#
#           2017       2018       2019       2020       2021  2022
# 0    7850871.0  7945580.0  8034305.0  8094317.0  8093815.0   NaN
# 1          9.8        9.9       10.0       10.1       10.1   NaN
# 2    3894093.0  3945584.0  3992323.0  4021817.0  4023278.0   NaN
# 3    3956778.0  3999996.0  4041982.0  4072500.0  4070537.0   NaN
# 4         36.7       36.7       36.8       37.2       37.7   NaN
# ..         ...        ...        ...        ...        ...   ...
# 808        NaN        NaN        NaN        NaN        NaN   NaN
# 809        NaN        NaN        NaN        NaN        NaN   NaN
# 810        NaN        NaN        NaN        NaN        NaN   NaN
# 811        NaN        NaN        NaN        NaN        NaN   NaN
# 812        NaN        NaN        NaN        NaN        NaN   NaN
#
# [813 rows x 12 columns]

# %%
NSW_mortgages.describe()
# Out:
#                2011          2015          2016          2017          2018  \
# count  2.290000e+02  2.000000e+01  6.640000e+02  3.190000e+02  3.560000e+02
# mean   7.601558e+05  8.022549e+06  1.205425e+06  1.034304e+06  9.678157e+05
# std    4.382216e+06  1.919068e+07  6.660952e+06  6.043868e+06  5.655944e+06
# min    1.000000e-01  2.500000e+01  1.600000e-01 -1.516100e+04 -2.167200e+04
# 25%    7.900000e+00  5.945000e+01  8.275000e+00  4.350000e+01  7.475000e+01
# 50%    5.970000e+01  4.079050e+04  1.121500e+03  4.479900e+04  3.749000e+04
# 75%    1.041870e+05  3.001438e+06  2.333072e+05  2.548945e+05  2.463378e+05
# max    5.356605e+07  8.012986e+07  8.012986e+07  8.012986e+07  8.012986e+07
#
#                2019          2020          2021          2022
# count  3.680000e+02  2.880000e+02  4.300000e+02     10.000000
# mean   8.985060e+05  1.062588e+06  8.598232e+05  29908.500000
# std    5.494994e+06  6.091499e+06  5.788766e+06  15919.674817
# min   -2.206300e+04 -2.088700e+04  3.000000e-01   9188.000000
# 25%    6.372500e+01  3.365000e+02  6.925000e+00  18656.000000
# 50%    3.468050e+04  4.361800e+04  1.344450e+04  25461.500000
# 75%    2.409035e+05  2.507555e+05  2.299635e+05  39085.750000
# max    8.012986e+07  8.012986e+07  8.007977e+07  55258.000000

# %%
NSW_mortgages.describe(include='all')
# Out:
#        Measure Code                                 Parent Description  \
# count           813                                                813
# unique          813                                                104
# top        ERP_P_20  Personal income in Australia - year ended 30 June
# freq              1                                                 41
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                         Description          2011          2015          2016  \
# count                           813  2.290000e+02  2.000000e+01  6.640000e+02
# unique                          772           NaN           NaN           NaN
# top     Not in the labour force (%)           NaN           NaN           NaN
# freq                              3           NaN           NaN           NaN
# mean                            NaN  7.601558e+05  8.022549e+06  1.205425e+06
# std                             NaN  4.382216e+06  1.919068e+07  6.660952e+06
# min                             NaN  1.000000e-01  2.500000e+01  1.600000e-01
# 25%                             NaN  7.900000e+00  5.945000e+01  8.275000e+00
# 50%                             NaN  5.970000e+01  4.079050e+04  1.121500e+03
# 75%                             NaN  1.041870e+05  3.001438e+06  2.333072e+05
# max                             NaN  5.356605e+07  8.012986e+07  8.012986e+07
#
#                 2017          2018          2019          2020          2021  \
# count   3.190000e+02  3.560000e+02  3.680000e+02  2.880000e+02  4.300000e+02
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    1.034304e+06  9.678157e+05  8.985060e+05  1.062588e+06  8.598232e+05
# std     6.043868e+06  5.655944e+06  5.494994e+06  6.091499e+06  5.788766e+06
# min    -1.516100e+04 -2.167200e+04 -2.206300e+04 -2.088700e+04  3.000000e-01
# 25%     4.350000e+01  7.475000e+01  6.372500e+01  3.365000e+02  6.925000e+00
# 50%     4.479900e+04  3.749000e+04  3.468050e+04  4.361800e+04  1.344450e+04
# 75%     2.548945e+05  2.463378e+05  2.409035e+05  2.507555e+05  2.299635e+05
# max     8.012986e+07  8.012986e+07  8.012986e+07  8.012986e+07  8.007977e+07
#
#                 2022
# count      10.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    29908.500000
# std     15919.674817
# min      9188.000000
# 25%     18656.000000
# 50%     25461.500000
# 75%     39085.750000
# max     55258.000000

# %%
NSW_mortgages.iloc[:, 0:].head()
# Out:
#   Measure Code                          Parent Description  \
# 0     ERP_P_20  Estimated resident population - at 30 June
# 1       ERP_21  Estimated resident population - at 30 June
# 2     ERP_M_20  Estimated resident population - at 30 June
# 3     ERP_F_20  Estimated resident population - at 30 June
# 4       ERP_19  Estimated resident population - at 30 June
#
#                                      Description  2011  2015       2016  \
# 0            Estimated resident population (no.)   NaN   NaN  7732858.0
# 1               Population density (persons/km2)   NaN   NaN        9.7
# 2    Estimated resident population - males (no.)   NaN   NaN  3833807.0
# 3  Estimated resident population - females (no.)   NaN   NaN  3899051.0
# 4                     Median age - males (years)   NaN   NaN       36.7
#
#         2017       2018       2019       2020       2021  2022
# 0  7850871.0  7945580.0  8034305.0  8094317.0  8093815.0   NaN
# 1        9.8        9.9       10.0       10.1       10.1   NaN
# 2  3894093.0  3945584.0  3992323.0  4021817.0  4023278.0   NaN
# 3  3956778.0  3999996.0  4041982.0  4072500.0  4070537.0   NaN
# 4       36.7       36.7       36.8       37.2       37.7   NaN

# %%
NSW_mortgages_DF = NSW_mortgages.iloc[[0,1,244,245,414,455,640,641,642,643,644,645,646,647,742,743,744,745,746,747,748,749], [0,1,2,5,6,7,8,9,10]]
NSW_mortgages_DF
# Out:
#     Measure Code                                 Parent Description  \
# 0       ERP_P_20         Estimated resident population - at 30 June
# 1         ERP_21         Estimated resident population - at 30 June
# 244   ING_TTYPE1                               Tenure type - Census
# 245   ING_TTYPE3                               Tenure type - Census
# 414    INCOME_36  Personal income in Australia - year ended 30 June
# 455      EQUIV_2  Equivalised total household income - Family, l...
# 640    STRESS_10  Mortgage and rent affordability indicators - O...
# 641    STRESS_11  Mortgage and rent affordability indicators - O...
# 642    STRESS_12  Mortgage and rent affordability indicators - O...
# 643    STRESS_13  Mortgage and rent affordability indicators - O...
# 644    STRESS_14  Mortgage and rent affordability indicators - O...
# 645    STRESS_15  Mortgage and rent affordability indicators - O...
# 646    STRESS_16  Mortgage and rent affordability indicators - O...
# 647    STRESS_17  Mortgage and rent affordability indicators - O...
# 742     INCMIG_2  Total personal income (weekly) of persons born...
# 743     INCMIG_3  Total personal income (weekly) of persons born...
# 744     INCMIG_4  Total personal income (weekly) of persons born...
# 745     INCMIG_5  Total personal income (weekly) of persons born...
# 746     INCMIG_6  Total personal income (weekly) of persons born...
# 747     INCMIG_7  Total personal income (weekly) of persons born...
# 748     INCMIG_8  Total personal income (weekly) of persons born...
# 749     INCMIG_9  Total personal income (weekly) of persons born...
#
#                                            Description       2016       2017  \
# 0                  Estimated resident population (no.)  7732858.0  7850871.0
# 1                     Population density (persons/km2)        9.7        9.8
# 244  Owner with or without a mortgage (or being pur...    82909.0        NaN
# 245  Owner with or without a mortgage (or being pur...       40.1        NaN
# 414  Mean total income (excl. Government pensions a...    64493.0    65196.0
# 455  Median equivalised total household income (wee...      891.0        NaN
# 640  Households where mortgage repayments are less ...        NaN        NaN
# 641  Households where mortgage repayments are more ...        NaN        NaN
# 642  Households where rent payments are less than o...        NaN        NaN
# 643  Households where rent payments are more than 3...        NaN        NaN
# 644  Households where mortgage repayments are less ...        NaN        NaN
# 645  Households where mortgage repayments are more ...        NaN        NaN
# 646  Households where rent payments are less than o...        NaN        NaN
# 647  Households where rent payments are more than 3...        NaN        NaN
# 742               Persons earning $1-$499 per week (%)       28.8        NaN
# 743             Persons earning $500-$999 per week (%)       22.7        NaN
# 744           Persons earning $1000-$1999 per week (%)       22.4        NaN
# 745           Persons earning $2000-$2999 per week (%)        5.7        NaN
# 746         Persons earning $3000 or more per week (%)        4.0        NaN
# 747                     Persons earning nil income (%)       12.8        NaN
# 748                 Persons with a negative income (%)        0.7        NaN
# 749    Income inadequately described or not stated (%)        2.9        NaN
#
#           2018       2019       2020       2021
# 0    7945580.0  8034305.0  8094317.0  8093815.0
# 1          9.9       10.0       10.1       10.1
# 244        NaN        NaN        NaN   115992.0
# 245        NaN        NaN        NaN       43.4
# 414    67200.0    68816.0        NaN        NaN
# 455        NaN        NaN        NaN     1096.0
# 640        NaN        NaN        NaN   677486.0
# 641        NaN        NaN        NaN   163060.0
# 642        NaN        NaN        NaN   529731.0
# 643        NaN        NaN        NaN   335404.0
# 644        NaN        NaN        NaN       71.9
# 645        NaN        NaN        NaN       17.3
# 646        NaN        NaN        NaN       56.1
# 647        NaN        NaN        NaN       35.5
# 742        NaN        NaN        NaN       23.2
# 743        NaN        NaN        NaN       22.4
# 744        NaN        NaN        NaN       25.7
# 745        NaN        NaN        NaN        8.3
# 746        NaN        NaN        NaN        6.6
# 747        NaN        NaN        NaN       10.5
# 748        NaN        NaN        NaN        0.7
# 749        NaN        NaN        NaN        2.5

# %%
NSW_mortgages_DF.set_index(NSW_mortgages_DF['Measure Code'])
NSW_mortgages_DF.head()
# Out:
#     Measure Code                                 Parent Description  \
# 0       ERP_P_20         Estimated resident population - at 30 June
# 1         ERP_21         Estimated resident population - at 30 June
# 244   ING_TTYPE1                               Tenure type - Census
# 245   ING_TTYPE3                               Tenure type - Census
# 414    INCOME_36  Personal income in Australia - year ended 30 June
#
#                                            Description       2016       2017  \
# 0                  Estimated resident population (no.)  7732858.0  7850871.0
# 1                     Population density (persons/km2)        9.7        9.8
# 244  Owner with or without a mortgage (or being pur...    82909.0        NaN
# 245  Owner with or without a mortgage (or being pur...       40.1        NaN
# 414  Mean total income (excl. Government pensions a...    64493.0    65196.0
#
#           2018       2019       2020       2021
# 0    7945580.0  8034305.0  8094317.0  8093815.0
# 1          9.9       10.0       10.1       10.1
# 244        NaN        NaN        NaN   115992.0
# 245        NaN        NaN        NaN       43.4
# 414    67200.0    68816.0        NaN        NaN

# %%
mortgages_stress_2021 = NSW_mortgages_DF.drop(columns=["Parent Description","Description","2016","2017","2018","2019","2020"])
mortgages_stress_2021.drop([0,1,244,245,414,455,742,743,744,745,746,747,748,749], axis=0, inplace=True)
Lower_income = mortgages_stress_2021.drop(index=[644,645,646,647])
Higher_income = mortgages_stress_2021.drop(index=[640,641,642,643])
mortgages_stress_2021.set_index(mortgages_stress_2021['Measure Code'], inplace=True)
mortgages_stress_2021.drop(columns=['Measure Code'], inplace=True)
mortgages_stress_2021
# Out:
#                   2021
# Measure Code
# STRESS_10     677486.0
# STRESS_11     163060.0
# STRESS_12     529731.0
# STRESS_13     335404.0
# STRESS_14         71.9
# STRESS_15         17.3
# STRESS_16         56.1
# STRESS_17         35.5

# %%
Higher_income.set_index(Higher_income['Measure Code'], inplace=True)
Higher_income.drop(columns=['Measure Code'], inplace=True)
Higher_income_plot = Higher_income['2021'].hvplot.bar(label="Household Mortgage Repayments of Higher Household Income")
Higher_income_plot
# Out:
# :Bars   [Measure Code]   (2021)

# %%
Lower_income.set_index(Lower_income['Measure Code'], inplace=True)
Lower_income.drop(columns=['Measure Code'], inplace=True)
Lower_income_plot = Lower_income['2021'].hvplot.bar(
    label="Household Mortgage Repayments of Lower Household Income",
    shared_axes = False)
Lower_income_plot
# Out:
# :Bars   [Measure Code]   (2021)

# %%
Higher_income_plot + Lower_income_plot
# Out:
# :Layout
#    .Bars.Household_Mortgage_Repayments_of_Higher_Household_Income :Bars   [Measure Code]   (2021)
#    .Bars.Household_Mortgage_Repayments_of_Lower_Household_Income  :Bars   [Measure Code]   (2021)

# %%
Higher_box = Higher_income.hvplot.box(y='2021',
shared_axes = False)

# %%
Lower_box = Lower_income.hvplot.box(y="2021",
shared_axes = False)

# %%
Lower_box + Higher_box
# Out:
# :Layout
#    .BoxWhisker.I  :BoxWhisker   (2021)
#    .BoxWhisker.II :BoxWhisker   (2021)
