# %%
#Total NSW MAP

import pandas as pd
import folium
from IPython.display import display


sydney_map = folium.Map(location=[-31.25, 146.92], zoom_start=7)

folium.Marker(
    location=[-32.92715, 151.77647],
    popup='Newcastle and Lake Macquarie',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-28.81354, 153.2773],
    popup='Richmond - Tweed',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.86785, 151.20732],
    popup='Sydney - City and Inner South',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-35.12577, 147.35375],
    popup='Riverina',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-31.9652, 141.4512],
    popup='Far West and Orana',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-35.282001, 149.128998],
    popup='Captal Region',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-32.733, 151.5574],
    popup='Hunter Valley exc Newcastle',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.89835, 151.17754],
    popup='Sydney - Inner West',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.347222, 151.496111],
    popup='Central Coast',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.283577, 149.101273],
    popup='Central West',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-30.50828, 151.67123],
    popup='New England and North West',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-36.07494, 146.92394],
    popup='Murray',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)


folium.Marker(
    location=[-34.4775, 150.4204],
    popup='Southern Highlands and Shoalhaven',
   icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.75881, 150.99292],
    popup='Sydney - Baulkham Hills and Hawkesbury',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(sydney_map)

folium.Marker(
    location=[-33.76667, 150.91667],
    popup='Blacktown',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.89103, 151.27157],
    popup='Sydney - Eastern Suburbs',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.8, 151.18333],
    popup='North Sydney and Hornsby',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.67596, 151.30653],
    popup='Northern Beaches',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(sydney_map)

folium.Marker(
    location=[-34.06667, 150.81667],
    popup='Sydney - Outer South West',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.75, 150.7],
    popup='Sydney - Outer West and Blue Mountains',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-30.29626, 153.11351],
    popup='Coffs Harbour - Grafton',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-31.43084, 152.90894],
    popup='Mid North Coast',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.81667, 151.0],
    popup='Sydney - Parramatta',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.91667, 151.03333],
    popup='Sydney - Inner South West',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.79677, 151.12436],
    popup='Sydney - Ryde',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.9, 150.93333],
    popup='Sydney - South West',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-34.0333, 151.05],
    popup='Sydney - Sutherland',
   icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-34.425072, 150.893143],
    popup='Illawarra',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)


display(sydney_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acd4e6f0595ee43293bceab80d36a717 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acd4e6f0595ee43293bceab80d36a717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acd4e6f0595ee43293bceab80d36a717 = L.map(
#                 &quot;map_acd4e6f0595ee43293bceab80d36a717&quot;,
#                 {
#                     center: [-31.25, 146.92],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1980b8b1b44adb762cd7a97afdc00092 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acd4e6f0595ee43293bceab80d36a717);
#
#
#             var marker_a1185ccad73695d9edf3d3e7cf92ed56 = L.marker(
#                 [-32.92715, 151.77647],
#                 {}
#             ).addTo(map_acd4e6f0595ee43293bceab80d36a717);
#
#
#             var icon_505bc6d5f6a41146a10e83e19fb1e1c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a1185ccad73695d9edf3d3e7cf92ed56.setIcon(icon_505bc6d5f6a41146a10e83e19fb1e1c4);
#
#
#         var popup_35f5292bde3883674cc3ae3fa5d8dc27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b1fe8b73e45865958086db1d43c95ca = $(`&lt;div id=&quot;html_2b1fe8b73e45865958086db1d43c95ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Newcastle and Lake Macquarie&lt;/div&gt;`)[0];
#                 popup_35f5292bde3883674cc3ae3fa5d8dc27.setContent(html_2b1fe8b73e45865958086db1d43c95ca);
#
#
#
#         marker_a1185ccad73695d9edf3d3e7cf92ed56.bindPopup(popup_35f5292bde3883674cc3ae3fa5d8dc27)
#         ;
#
#
#
#
#             var marker_b1e823ca86955472168651054545dd8a = L.marker(
#                 [-28.81354, 153.2773],
#                 {}
#             ).addTo(map_acd4e6f0595ee43293bceab80d36a717);
#
#
#             var icon_04d44f24c200e0906b56ca05062a9645 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;orange&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b1e823ca86955472168651054545dd8a.setIcon(icon_04d44f24c200e0906b56ca05062a9645);
#
#
#         var popup_a308f317c57de862cdff7558c7d2a1e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b1d18d445782b2001318eedf75a94e0 = $(`&lt;div id=&quot;html_7b1d18d445782b2001318eedf75a94e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Richmond - Tweed&lt;/div&gt;`)[0];
#                 popup_a308f317c57de862cdff7558c7d2a1e2.setContent(html_7b1d18d445782b2001318eedf75a94e0);
#
#
#
#         marker_b1e823ca86955472168651054545dd8a.bindPopup(popup_a308f317c57de862cdff7558c7d2a1e2)
#         ;
#
#
#
#
#             var marker_773e50c8a480a8cdb46a52ea0614cbeb = L.marker(
#                 [-33.86785, 151.20732],
#                 {}
#             ).addTo(map_acd4e6f0595ee43293bceab80d36a717);
#
#
#             var icon_649f05f08219665081db88025b355bea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;orange&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_773e50c8a480a8cdb46a52ea0614cbeb.setIcon(icon_649f05f08219665081db88025b355bea);
#
#
#         var popup_649ca7f096f22b1e049ba014db1bcde4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae0ca85b8ea0f0e74634922746cf372e = $(`&lt;div id=&quot;html_ae0ca85b8ea0f0e74634922746cf372e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sydney - City and Inner South&lt;/div&gt;`)[0];
#                 popup_649ca7f096f22b1e049ba014db1bcde4.setContent(html_ae0ca85b8ea0f0e74634922746cf372e);
#
#
#
#         marker_773e50c8a480a8cdb46a52ea0614cbeb.bindPopup(popup_649ca7f096f22b1e049ba014db1bcde4)
#         ;
#
#
#
#
#             var marker_ec4d35e79092fbf3380eb9d13f5493a0 = L.marker(
#                 [-35.12577, 147.35375],
#                 {}
#             ).addTo(map_acd4e6f0595ee43293bceab80d36a717);
#
#
#             var icon_3a47d3cb559510ef78f8616e37931b2a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot

# %%
#Northern Beaches Map:
import pandas as pd
import folium
from IPython.display import display

nb_map = folium.Map(location=[-33.67596, 151.30653], zoom_start=11)

folium.Marker(
    location=[-33.794940, 151.257200],
    popup='Balgowlah - Clontarf - Seaforth',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(nb_map)

folium.Marker(
    location=[-33.797980, 151.288260],
    popup='Manly - Fairlight',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(nb_map)

folium.Marker(
    location=[-33.635030, 151.330100],
    popup='Avalon - Palm Beach',
    icon=folium.Icon(icon='info-sign', icon_color='purple')
).add_to(nb_map)

folium.Marker(
    location=[-33.662470, 151.292790],
    popup='Bayview - Elanora Heights',
    icon=folium.Icon(icon='info-sign', icon_color='purple')
).add_to(nb_map)

folium.Marker(
    location=[-33.655170, 151.321260],
    popup='Newport - Bilgola',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(nb_map)

folium.Marker(
    location=[-33.688570, 151.295340],
    popup='Mona Vale - Warriewood (North)',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

folium.Marker(
    location=[-33.709350, 151.296070],
    popup='North Narrabeen - Warriewood (South)',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

folium.Marker(
    location=[-33.635030, 151.330100],
    popup='Avalon - Palm Beach',
    icon=folium.Icon(icon='info-sign', icon_color='purple')
).add_to(nb_map)

folium.Marker(
    location=[-33.752406, 151.261272],
    popup='Beacon Hill - Narraweena',
    icon=folium.Icon(icon='info-sign', icon_color='purple')
).add_to(nb_map)

folium.Marker(
    location=[-33.728010, 151.265590],
    popup='Cromer',
    icon=folium.Icon(icon='info-sign', icon_color='purple')
).add_to(nb_map)

folium.Marker(
    location=[-33.766670, 151.208330],
    popup='Forestville - Killarney Heights',
    icon=folium.Icon(icon='info-sign', icon_color='purple')
).add_to(nb_map)

folium.Marker(
    location=[-33.778670, 151.285690],
    popup='Freshwater - Brookvale',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(nb_map)

folium.Marker(
    location=[-33.800000, 151.283330],
    popup='Manly Vale - Allambie Heights',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(nb_map)

folium.Marker(
    location=[-33.683212, 151.224396],
    popup='Terrey Hills - Duffys Forest',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(nb_map)

folium.Marker(
    location=[-33.739540, 151.210330],
    popup='Belrose',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

folium.Marker(
    location=[-33.731760, 151.301460],
    popup='Collaroy - Collaroy Plateau',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

folium.Marker(
    location=[-33.762686, 151.290001],
    popup='Dee Why (South) - North Curl Curl',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

folium.Marker(
    location=[-33.753562, 151.286140],
    popup='Dee Why - North',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

folium.Marker(
    location=[-33.748980, 151.224470],
    popup='Frenchs Forest - Oxford Falls',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

folium.Marker(
    location=[-33.712770, 151.297360],
    popup='Narrabeen - Wheeler Heights',
    icon=folium.Icon(icon='info-sign', icon_color='white')
).add_to(nb_map)

from IPython.display import display
display(nb_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0de09bdb805d0bfb7cfff8a55fa22752 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0de09bdb805d0bfb7cfff8a55fa22752&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0de09bdb805d0bfb7cfff8a55fa22752 = L.map(
#                 &quot;map_0de09bdb805d0bfb7cfff8a55fa22752&quot;,
#                 {
#                     center: [-33.67596, 151.30653],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7662a35a7066033dcf39f3c47f5c091f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0de09bdb805d0bfb7cfff8a55fa22752);
#
#
#             var marker_afd7a433dfab32eb472defe8c061b497 = L.marker(
#                 [-33.79494, 151.2572],
#                 {}
#             ).addTo(map_0de09bdb805d0bfb7cfff8a55fa22752);
#
#
#             var icon_0f6d79bfb045c0fcffcd5fcde390b7c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_afd7a433dfab32eb472defe8c061b497.setIcon(icon_0f6d79bfb045c0fcffcd5fcde390b7c6);
#
#
#         var popup_882029058a134492b9ec5b5b4fe08a78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_deda5862c1e43338c79929bf50def91c = $(`&lt;div id=&quot;html_deda5862c1e43338c79929bf50def91c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Balgowlah - Clontarf - Seaforth&lt;/div&gt;`)[0];
#                 popup_882029058a134492b9ec5b5b4fe08a78.setContent(html_deda5862c1e43338c79929bf50def91c);
#
#
#
#         marker_afd7a433dfab32eb472defe8c061b497.bindPopup(popup_882029058a134492b9ec5b5b4fe08a78)
#         ;
#
#
#
#
#             var marker_533d4c0e9d88d732157c213a27e33308 = L.marker(
#                 [-33.79798, 151.28826],
#                 {}
#             ).addTo(map_0de09bdb805d0bfb7cfff8a55fa22752);
#
#
#             var icon_e31946abfb829b9234458aea6eb85a3c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_533d4c0e9d88d732157c213a27e33308.setIcon(icon_e31946abfb829b9234458aea6eb85a3c);
#
#
#         var popup_7640ad30cd15e7da5874db1f1300c01e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a71246aab460282a7137455ea34a85c = $(`&lt;div id=&quot;html_9a71246aab460282a7137455ea34a85c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manly - Fairlight&lt;/div&gt;`)[0];
#                 popup_7640ad30cd15e7da5874db1f1300c01e.setContent(html_9a71246aab460282a7137455ea34a85c);
#
#
#
#         marker_533d4c0e9d88d732157c213a27e33308.bindPopup(popup_7640ad30cd15e7da5874db1f1300c01e)
#         ;
#
#
#
#
#             var marker_44f78cfe493fbb11f846c763301cb2ce = L.marker(
#                 [-33.63503, 151.3301],
#                 {}
#             ).addTo(map_0de09bdb805d0bfb7cfff8a55fa22752);
#
#
#             var icon_f17ba4f81995647e6c25215c9d714c82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;purple&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_44f78cfe493fbb11f846c763301cb2ce.setIcon(icon_f17ba4f81995647e6c25215c9d714c82);
#
#
#         var popup_e41da75548b496743fa7c7b81c1e1b1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d58fe311fa21913a1c4524fb9daeeb40 = $(`&lt;div id=&quot;html_d58fe311fa21913a1c4524fb9daeeb40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avalon - Palm Beach&lt;/div&gt;`)[0];
#                 popup_e41da75548b496743fa7c7b81c1e1b1f.setContent(html_d58fe311fa21913a1c4524fb9daeeb40);
#
#
#
#         marker_44f78cfe493fbb11f846c763301cb2ce.bindPopup(popup_e41da75548b496743fa7c7b81c1e1b1f)
#         ;
#
#
#
#
#             var marker_1c6106562446f5115e027eb84fb50fce = L.marker(
#                 [-33.66247, 151.29279],
#                 {}
#             ).addTo(map_0de09bdb805d0bfb7cfff8a55fa22752);
#
#
#             var icon_ceac0854873a67b5e4802b700f0baf73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
