# %%
#Total NSW MAP

import pandas as pd
import folium
from geopy.geocoders import Nominatim


sydney_map = folium.Map(location=[-31.25, 146.92], zoom_start=7)

folium.Marker(
    location=[-32.92715, 151.77647],
    popup='Newcastle and Lake Macquarie',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-28.81354, 153.2773],
    popup='Richmond - Tweed',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.86785, 151.20732],
    popup='Sydney - City and Inner South',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-35.12577, 147.35375],
    popup='Riverina',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-31.9652, 141.4512],
    popup='Far West and Orana',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-35.282001, 149.128998],
    popup='Captal Region',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-32.733, 151.5574],
    popup='Hunter Valley exc Newcastle',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.89835, 151.17754],
    popup='Sydney - Inner West',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.347222, 151.496111],
    popup='Central Coast',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.283577, 149.101273],
    popup='Central West',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-30.50828, 151.67123],
    popup='New England and North West',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)

folium.Marker(
    location=[-36.07494, 146.92394],
    popup='Murray',
    icon=folium.Icon(icon='info-sign', icon_color='green')
).add_to(sydney_map)


folium.Marker(
    location=[-34.4775, 150.4204],
    popup='Southern Highlands and Shoalhaven',
   icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.75881, 150.99292],
    popup='Sydney - Baulkham Hills and Hawkesbury',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(sydney_map)

folium.Marker(
    location=[-33.76667, 150.91667],
    popup='Blacktown',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.89103, 151.27157],
    popup='Sydney - Eastern Suburbs',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.8, 151.18333],
    popup='North Sydney and Hornsby',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.67596, 151.30653],
    popup='Northern Beaches',
    icon=folium.Icon(icon='info-sign', icon_color='red')
).add_to(sydney_map)

folium.Marker(
    location=[-34.06667, 150.81667],
    popup='Sydney - Outer South West',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.75, 150.7],
    popup='Sydney - Outer West and Blue Mountains',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-30.29626, 153.11351],
    popup='Coffs Harbour - Grafton',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-31.43084, 152.90894],
    popup='Mid North Coast',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

folium.Marker(
    location=[-33.81667, 151.0],
    popup='Sydney - Parramatta',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.91667, 151.03333],
    popup='Sydney - Inner South West',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.79677, 151.12436],
    popup='Sydney - Ryde',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-33.9, 150.93333],
    popup='Sydney - South West',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-34.0333, 151.05],
    popup='Sydney - Sutherland',
   icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

folium.Marker(
    location=[-34.425072, 150.893143],
    popup='Illawarra',
    icon=folium.Icon(icon='info-sign', icon_color='orange')
).add_to(sydney_map)

from IPython.display import display
display(sydney_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Northern Beaches Map:
import pandas as pd
import folium
from geopy.geocoders import Nominatim

sydney_map = folium.Map(location=[-31.25, 146.92], zoom_start=7)

folium.Marker(
    location=[-32.92715, 151.77647],
    popup='Newcastle and Lake Macquarie',
    icon=folium.Icon(icon='info-sign', icon_color='yellow')
).add_to(sydney_map)

from IPython.display import display
display(sydney_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
